# %%
products = [
				{
				"name": "Laptop",
				"price": 70000,
				"brand": "Dell"
				},
				{
				"name": "Phone",
				"price": 40000,
				"brand": "Samsung"
				},
				{
				"name": "Tablet",
				"price": 30000,
				"brand": "Apple"
				}
           ]

# %%
# Print all products
print(products)
# Out:
# [{'name': 'Laptop', 'price': 70000, 'brand': 'Dell'}, {'name': 'Phone', 'price': 40000, 'brand': 'Samsung'}, {'name': 'Tablet', 'price': 30000, 'brand': 'Apple'}]

# %%
# Print first product
products[0]
# Out:
# {'name': 'Laptop', 'price': 70000, 'brand': 'Dell'}

# %%
# Print second product's price
products[1]['price']
# Out:
# 40000

# %%
# Print third product's brand
products[2]['brand']
# Out:
# 'Apple'

# %%
# Change first product's price
products[0]['price'] = "100000"
products
# Out:
# [{'name': 'Laptop', 'price': '100000', 'brand': 'Dell'},
#  {'name': 'Phone', 'price': 40000, 'brand': 'Samsung'},
#  {'name': 'Tablet', 'price': 30000, 'brand': 'Apple'}]

# %%
# Add "rating" to the second product
products[1]['rating'] = 5
products
# Out:
# [{'name': 'Laptop', 'price': '100000', 'brand': 'Dell'},
#  {'name': 'Phone', 'price': 40000, 'brand': 'Samsung', 'rating': 5},
#  {'name': 'Tablet', 'price': 30000, 'brand': 'Apple'}]

# %%
# Add another product manually
products.append({'name': 'Ipad', 'price': '55000', 'brand': 'Apple'})

# %%
# Print the final dataset
products
# Out:
# [{'name': 'Laptop', 'price': '100000', 'brand': 'Dell'},
#  {'name': 'Phone', 'price': 40000, 'brand': 'Samsung', 'rating': 5},
#  {'name': 'Tablet', 'price': 30000, 'brand': 'Apple'},
#  {'name': 'Ipad', 'price': '55000', 'brand': 'Apple'}]
