# %%
name = "Bharadwaj"
print("My name is:",name)
age = 34
print("My age is:",age)
city = "Hyderabad"
print("Current city is:",city)
company = "XYZ technologies"
print("Working for:",company)
topic = "python"
print("I'm current learning:",topic)
experience = 11.5
print(f"My experience is, {experience} years")
like_python = True
print("Do I like python:",like_python)
expected_salary = 30
print(f"Expected salary is: {expected_salary} lpa")
# Out:
# My name is: Bharadwaj
# My age is: 34
# Current city is: Hyderabad
# Working for: XYZ technologies
# I'm current learning: python
# My experience is, 11.5 years
# Do I like python: True
# Expected salary is: 30 lpa

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(city)
# Out:
# str

# %%
type(company)
# Out:
# str

# %%
type(topic)
# Out:
# str

# %%
type(experience)
# Out:
# float

# %%
type(like_python)
# Out:
# bool

# %%
type(expected_salary)
# Out:
# int
