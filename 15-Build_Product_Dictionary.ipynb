# %%
laptop = {
"brand": "Dell",
"model": "XPS 15",
"price": 120000,
"ram": "16GB",
"storage": "512GB SSD",
"available": True
}

# %%
# Display the product
print(laptop)
# Out:
# {'brand': 'Dell', 'model': 'XPS 15', 'price': 120000, 'ram': '16GB', 'storage': '512GB SSD', 'available': True}

# %%
# Print brand
print(laptop['brand'])
# Out:
# Dell

# %%
# Print model
print(laptop['model'])
# Out:
# XPS 15

# %%
# Print price
print(laptop['price'])
# Out:
# 120000

# %%
# Change price
laptop['price'] = '150000'
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': '150000',
#  'ram': '16GB',
#  'storage': '512GB SSD',
#  'available': True}

# %%
# Add processor information
laptop['processor'] = 'Intel'
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': '150000',
#  'ram': '16GB',
#  'storage': '512GB SSD',
#  'available': True,
#  'processor': 'Intel'}

# %%
# Add GPU information
laptop['GPU'] = '12GB'
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': '150000',
#  'ram': '16GB',
#  'storage': '512GB SSD',
#  'available': True,
#  'processor': 'Intel',
#  'GPU': '12GB'}

# %%
# Change RAM to "32GB"
laptop['ram'] = '32GB'
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': '150000',
#  'ram': '32GB',
#  'storage': '512GB SSD',
#  'available': True,
#  'processor': 'Intel',
#  'GPU': '12GB'}

# %%
# Remove "available"
laptop.pop("available")
laptop
# Out:
# {'brand': 'Dell',
#  'model': 'XPS 15',
#  'price': '150000',
#  'ram': '32GB',
#  'storage': '512GB SSD',
#  'processor': 'Intel',
#  'GPU': '12GB'}

# %%
# Print all keys
print(laptop.keys())
# Out:
# dict_keys(['brand', 'model', 'price', 'ram', 'storage', 'processor', 'GPU'])

# %%
# Print all values
print(laptop.values())
# Out:
# dict_values(['Dell', 'XPS 15', '150000', '32GB', '512GB SSD', 'Intel', '12GB'])

# %%
# Print all items
print(laptop.items())
# Out:
# dict_items([('brand', 'Dell'), ('model', 'XPS 15'), ('price', '150000'), ('ram', '32GB'), ('storage', '512GB SSD'), ('processor', 'Intel'), ('GPU', '12GB')])

# %%
# Finally, create a second product dictionary for a mobile phone.
mobile = {
"brand": "Iphone",
"model": "17pro",
"price": 150000,
"ram": "5GB",
"storage": "512GB",
"available": True
}

mobile
# Out:
# {'brand': 'Iphone',
#  'model': '17pro',
#  'price': 150000,
#  'ram': '5GB',
#  'storage': '512GB',
#  'available': True}
