# %%
# int
age = 25
runs = 100

# float
price = 19.99
height = 5.9

# str
name = "Alice"
message = "Hello, World!"

# bool (boolean - True/False)
is_active = True
is_valid = False

# list (ordered, mutable collection)
numbers = [1, 2, 3, 4, 5]
fruits = ["apple", "banana", "orange"]

# tuple (ordered, immutable collection)
coordinates = (10, 20)
rgb_color = (255, 128, 0)

# set (unordered, unique values)
unique_numbers = {1, 2, 3, 4, 5}
tags = {"python", "data", "science"}

# dict (key-value pairs)
person = {"name": "Bob", "age": 30, "city": "NYC"}
scores = {"math": 95, "english": 88, "science": 92}

# %%
type(age)
# Out:
# int

# %%
type(runs)
# Out:
# int

# %%
type(price)
# Out:
# float

# %%
type(height)
# Out:
# float

# %%
type(name)
# Out:
# str

# %%
type(message)
# Out:
# str

# %%
type(is_active)
# Out:
# bool

# %%
type(is_valid)
# Out:
# bool

# %%
type(numbers)
# Out:
# list

# %%
type(fruits)
# Out:
# list

# %%
type(coordinates)
# Out:
# tuple

# %%
type(rgb_color)
# Out:
# tuple

# %%
type(unique_numbers)
# Out:
# set

# %%
type(tags)
# Out:
# set

# %%
type(person)
# Out:
# dict

# %%
type(scores)
# Out:
# dict

# %%
# typecasting of int to str
# str datatype values cannot be typecasted to int
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 2
#       1 # typecasting examples
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Alice'

# %%
# typecasting of float to str
float("19.99")
# Out:
# 19.99

# %%
# typecasting of int to str
str(runs)
# Out:
# '100'

# %%
# typecasting of tuple to list
# returns True because in Python, any non-zero number is considered truthy.
bool(25)
# Out:
# True

# %%
# typecasting of tuple to list
list(rgb_color)
# Out:
# [255, 128, 0]

# %%
# typecasting of list to tuple
tuple(fruits)
# Out:
# ('apple', 'banana', 'orange')

# %%
# typecasting of list to set
set(fruits)
# Out:
# {'apple', 'banana', 'orange'}
