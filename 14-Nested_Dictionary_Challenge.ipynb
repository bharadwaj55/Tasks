# %%
employee = {
"name": "Amit",
"department": "Engineering",
"skills": {
"language": "Python",
"database": "PostgreSQL",
"cloud": "AWS"
},
"salary": 80000
}

# %%
print(employee)
# Out:
# {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python', 'database': 'PostgreSQL', 'cloud': 'AWS'}, 'salary': 80000}

# %%
# Print employee name
print(employee['name'])
# Out:
# Amit

# %%
# Print department
print(employee['department'])
# Out:
# Engineering

# %%
# Print complete skills dictionary
print(employee['skills'])
# Out:
# {'language': 'Python', 'database': 'PostgreSQL', 'cloud': 'AWS'}

# %%
# Print programming language
print(employee['skills']['language'])
# Out:
# Python

# %%
# Print database
print(employee['skills']['database'])
# Out:
# PostgreSQL

# %%
# Print cloud technology
print(employee['skills']['cloud'])
# Out:
# AWS

# %%
# Change "Python" to "Python + JavaScript"
employee['skills']['language']="Python + JavaScript"
print(employee)
# Out:
# {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS'}, 'salary': 80000}

# %%
# Change salary
employee['salary'] = 100000
print(employee)
# Out:
# {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS'}, 'salary': 100000}

# %%
# Add "experience": 3
employee['experience'] = 3
print(employee)
# Out:
# {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS'}, 'salary': 100000, 'experience': 3}

# %%
# Add another skill under the skills dictionary
employee['skills']['vcs'] = "Git"
print(employee)
# Out:
# {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS', 'vcs': 'Git'}, 'salary': 100000, 'experience': 3}

# %%
# Explain how nested dictionaries are accessed.
# In dictionaries, we usually try to access the values using keys
# If there are nested dictionaries, initially we access the top level key first
# and then we proceed further to key in the level-2
# In such a way, using the keys, we can access and update the values in the dictionary
